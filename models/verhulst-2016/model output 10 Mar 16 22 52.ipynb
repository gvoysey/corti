# %% [markdown]
# #testing

# %%
    import numpy as np
    from datetime import datetime
    import matplotlib as mpl
    import matplotlib.pyplot as plt
    matplotlib inline

# %%
ls
# Out:
# ANF_Sarah.py                        analysis/                           cochlear_model_old.py               periphery_configuration.py          tridiag.so
# Sarah_ihc.py                        base.py                             model output 10 Mar 16 22 52.ipynb  requirements.txt                    tridiag.so_maccompiled
# __init__.py                         brainstem.py                        out/                                run_periphery.py                    tridiag.so_ubuntucompiled
# __pycache__/                        cochlea_utils.c                     output/                             sysfiles/                           voysey - startup instructions.md

# %%
cd output
# Out:
# /Users/gvoysey/Projects/thesis-code/models/verhulst-2016/output

# %%
ls
# Out:
# 10 Mar 16 - 2252/

# %%
cd "10 Mar 16 - 2252/"
# Out:
# /Users/gvoysey/Projects/thesis-code/models/verhulst-2016/output/10 Mar 16 - 2252

# %%
import numpy as np
result = np.load("anfH1.npy")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(result);
